# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderZiyatdinov/Kontinuum/blob/main/Practise_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практика 4. Выполнение алгоритмов для исполнителя

# %% [markdown]
# ![eFnLdHTUwOI.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Видео
# [Вебинар Коли](https://vk.com/inf2021?z=video-198702273_456239052%2F610df35fe0cbfc83a8%2Fpl_wall_-198702273)
#
# [Разбор задачки на ютубчике](https://www.youtube.com/watch?v=YSRRm7quVaI)
#
#
# [Разбор задачки от ГУРУ](https://www.youtube.com/watch?v=wUoQkYfQaa4&list=PL66kIi3dt8A5slbxnwIjiYHloR1VGE-UJ&index=10)

# %% [markdown]
# ## Теория
# [Задание 12](https://docviewer.yandex.ru/view/322310782/?page=1&*=ZApWZQxcCuksyGi0h3%...%3D%3D)
#
# [Немного теории об исполнителях](https://foxford.ru/wiki/informatika/ispolniteli-algoritmov)

# %% [markdown]
# ## Что нужно, чтобы решать задачки:
#
# *   правила выполнения линейных, разветвляющихся и циклических алгоритмов
# *   основные операции с символьными строками (определение длины, выделение
# подстроки, удаление и вставка символов, «сцепка» двух строк в одну)
#
#
# *   исполнитель – это человек, группа людей, животное, машина или другой объект,
# который может понимать и выполнять некоторые команды
# *   в школьном алгоритмическом языке нц обозначает «начало цикла», а кц – «конец
# цикла»; все команды между нц и кц – это тело цикла, они выполняются несколько раз
# запись нц для i от 1 до n обозначает начало цикла, в котором переменная i
# (она называется переменной цикла) принимает последовательно все значения от 1 до n с шагом
# 1
#
# **Примечание:**
#
# Данное задание можно решить с использованием Языков Программирования. К тому же во многих школах уже начинают учить программировать на Python, а не на алгоритмическом языке Ершова.

# %% [markdown]
# ### **Задание 1**
# 1. Задание 12 № 15951
#
# Какая строка получится в результате применения приведённой ниже программы к строке, состоящей
# из 98 единиц?
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (1111)
#
#
# заменить (1111, 22)
#
#
# заменить (222, 1)
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 2**
# Какая строка получится в результате применения приведённой ниже программы к строке вида 1…
# 12…2 (8 единиц, затем 8 двоек)?
#
# В ответе запишите полученную строку.
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (111) ИЛИ нашлось (222)
#
#
# ЕСЛИ нашлось (111)
#
#
# ТО заменить (111, 2)
#
#
# КОНЕЦ ЕСЛИ
#
#
# ЕСЛИ нашлось (222)
#
#
# ТО заменить (222, 1)
#
#
# КОНЕЦ ЕСЛИ
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 3**
#
# Дана программа для Редактора:
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (11)
#
#
# ЕСЛИ нашлось (112)
#
#
# ТО заменить (112, 6)
#
#
# ИНАЧЕ заменить (11, 3)
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ
#
#
# Исходная строка содержит десять единиц и три двойки, других цифр нет, точный порядок
# расположения единиц и двоек неизвестен. Какую наибольшую сумму цифр может иметь строка, которая
# получится после выполнения программы?

# %% [markdown]
# ### **Задание 4**
#
# Дана программа для Редактора:
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (>1) ИЛИ нашлось (>2) ИЛИ нашлось (>3)
#
#
# ЕСЛИ нашлось (>1)
#
#
# ТО заменить (>1, 22>)
#
#
# КОНЕЦ ЕСЛИ
#
#
# ЕСЛИ нашлось (>2)
#
#
# ТО заменить (>2, 2>)
#
#
# КОНЕЦ ЕСЛИ
#
#
# ЕСЛИ нашлось (>3)
#
#
# ТО заменить (>3, 1>)
#
#
# КОНЕЦ ЕСЛИ
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ
#
#
# На вход приведённой ниже программе поступает строка, начинающаяся с символа «>», а затем
# содержащая 26 цифр 1, 10 цифр 2 и 14 цифр 3, расположенных в произвольном порядке.
# Определите сумму числовых значений цифр строки, получившейся в результате выполнения
# программы. Так, например, если результат работы программы представлял бы собой строку, состоящую из 50 цифр 4, то верным ответом было бы число 200

# %% [markdown]
# ### **Задание 5**
#
# Какая строка получится в результате применения приведённой ниже программы к строке вида 1…
# 12…2 (40 единиц и 40 двоек)?
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (111)
#
#
# заменить (111, 2)
#
#
# заменить (222, 1)
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 6**
# Какая строка получится в результате применения приведённой ниже программы к строке, состоящей
# из 99 единиц?
#
# НАЧАЛО
#
#
# ПОКА нашлось (111)
#
#
# ЕСЛИ нашлось (222)
#
#
# ТО заменить (222, 1)
#
#
# ИНАЧЕ заменить (111, 2)
#
#
# КОНЕЦ ЕСЛИ
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 7**
# Найдите сумму цифр в строке, которая получится в результате применения приведённой ниже
# программы к строке, состоящей из 65 цифр 9.
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (999) ИЛИ нашлось (222)
#
#
# ЕСЛИ нашлось (222)
#
#
# ТО заменить (222, 9)
#
#
# ИНАЧЕ
#
#
# заменить (999, 2)
#
#
# КОНЕЦ ЕСЛИ
#
#
# КОНЕЦ ПОКА
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 8**
# Какая строка получится в результате применения приведённой ниже программы к строке, состоящей
# из 127 идущих подряд цифр «9»? В ответе запишите полученную строку.
#
#
# НАЧАЛО
#
#
# ПОКА нашлось (333) ИЛИ нашлось (999)
#
#
# ЕСЛИ нашлось (333)
#
#
# ТО заменить (333, 9)
#
#
# ИНАЧЕ заменить (999, 3)
#
#
# КОНЕЦ ЕСЛИ
#
#
# КОНЕЦ

# %% [markdown]
# ### **Задание 9**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 10**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 11**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 12**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 13**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 14**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 15**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 16**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 17**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 18**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 19**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Задание 20**
# Исполнитель Чертёжник-3D перемещается в пространстве, оставляя след в
# виде линии. Чертёжник-3D может выполнять команду
#
# **Сместиться на (a, b, c)**
#
#
# (где a, b, c – целые числа), перемещающую его из точки с координатами (x, y, z) в точку с
# координатами (x + a, y + b, z + c). Чертёжнику был дан для исполнения следующий алгоритм:
#
#
# Сместиться на (4, 8, 10)
#
#
# ПОВТОРИ 4 РАЗ
#
#
# Сместиться на (2, -4, -5)
#
#
# Сместиться на (a1, b1, c1)
#
#
# КОНЕЦ ПОВТОРИ
#
#
# На какие значения a1, b1, c1 нужно сместиться Чертёжнику-3D в цикле, чтобы начиная работу из
# точки с координатами (0, 0, 2), после выполнения данного алгоритма оказаться в точке с
# координатами (24, 16, 12)?
#
#
# Пример: если a1 = 10, b1 = 5, c1 = 22, то в ответе следует записать 10522 без пробелов и
# разделителей.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Мотивация
#
# [Изучение Computer Science](https://www.youtube.com/watch?v=BbOkf586700&t=708s)
#
# [ДРАКОН](https://www.youtube.com/watch?v=Bj6l0W2BBnM)
#
# [Коротко про машину Тьюринга](https://www.youtube.com/watch?v=Fo7Q4cKkbLs)
#
# [Цепи Маркова](https://www.youtube.com/watch?v=FROlGrwo-oo)
